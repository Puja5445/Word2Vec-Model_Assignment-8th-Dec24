# %%
import pandas as pd
import numpy as np
import os
import gensim
import nltk

# %%
nltk.download("all")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# ...

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
story=[]

# %%
# Step 1: Load the text file
file_path = '/content/The_Mahabharat Epic.txt'

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', 'The_Mahabharat Epic.txt', 'sample_data']

# %%
f = open(r"/content/The_Mahabharat Epic.txt",encoding='unicode_escape')

# %%
corpus=f.read()

# %%
print(corpus)
# Out:
# The Mah?bh?rata (/m??h???b??r?t?, ?m??h?-/ m?-HAH-BAR-?-t?, MAH-h?-;[1][2][3][4] Sanskrit: ?????????, IAST: Mah?bh?ratam, pronounced [m??a??b?a?r?t??m]) is one of the two major Smriti texts and Sanskrit epics of ancient India revered in Hinduism, the other being the R?m?ya?a.[5] It narrates the events and aftermath of the Kurukshetra War, a war of succession between two groups of princely cousins, the Kauravas and the P???avas.
# Part of a series on
# Hindu mythology
#
# Sources
# * Itihasa
# *
# * Ramayana
# * Mahabharata
# * Puranas
# *
# * Brahma Purana
# * Brahmanda Purana
# * Bhagavata Purana
# * Garuda Purana
# * Vishnu Purana
# * Shiva Purana
# * Skanda Purana
# * Markandeya Purana
# * Matsya Purana
# * Padma Purana
# * Vayu Purana
# Cosmology
# * Brahman
# * Hiranyagarbha
# * Svarga
# * Prithvi
# * Patala
# * Naraka
# * Satyaloka
# * Vaikuntha
# * Kailasha
# * Manidvipa
# Deities
# * Trimurti
# * Brahma
# * Vishnu
# * Shiva
# * Tridevi
# * Saraswati
# * Lakshmi
# * Parvati
# ...

# %%
raw_sent=sent_tokenize(corpus)

# %%
raw_sent
# Out:
# ['The\xa0Mah?bh?rata\xa0(/m??h???b??r?t?,\xa0?m??h?-/\xa0m?-HAH-BAR-?-t?,\xa0MAH-h?-;[1][2][3][4]\xa0Sanskrit:\xa0?????????,\xa0IAST:\xa0Mah?bh?ratam,\xa0pronounced\xa0[m??a??b?a?r?t?',
#  '?m]) is one of the two major\xa0Smriti\xa0texts and Sanskrit\xa0epics\xa0of\xa0ancient India\xa0revered in\xa0Hinduism, the other being the\xa0R?m?ya?a.',
#  '[5]\xa0It narrates the events and aftermath of the\xa0Kurukshetra War, a\xa0war of succession\xa0between two groups of princely cousins, the\xa0Kauravas\xa0and the\xa0P???avas.',
# ...

# %% [markdown]
# simple_preprocess():
#
# A function provided by the Gensim library to preprocess text.
# It tokenizes a string into lowercase words, removes punctuation, non-alphabetic characters, and filters out short words (default length ≤ 2).
# Loop (for i in raw_sent):
#
# Iterates over each sentence in raw_sent.
# Preprocessing and Printing:
#
# For each sentence (i), simple_preprocess(i) tokenizes and cleans it. The resulting list of tokens (words) is printed.
# What It Does:
# Breaks each sentence into a list of clean, lowercase tokens (words).
# Removes punctuation, special characters, and very short words (length ≤ 2).
# This is often a preparatory step for tasks like training word embeddings (e.g., Word2Vec) or building NLP models.

# %%
for i in raw_sent:
  print(simple_preprocess(i))
# Out:
# ['the', 'mah', 'bh', 'rata', 'hah', 'bar', 'mah', 'sanskrit', 'iast', 'mah', 'bh', 'ratam', 'pronounced']
# ['is', 'one', 'of', 'the', 'two', 'major', 'smriti', 'texts', 'and', 'sanskrit', 'epics', 'of', 'ancient', 'india', 'revered', 'in', 'hinduism', 'the', 'other', 'being', 'the', 'ya']
# ['it', 'narrates', 'the', 'events', 'and', 'aftermath', 'of', 'the', 'kurukshetra', 'war', 'war', 'of', 'succession', 'between', 'two', 'groups', 'of', 'princely', 'cousins', 'the', 'kauravas', 'and', 'the', 'avas']
# ...

# %%
file_path=r"/content/The_Mahabharat Epic.txt"

# %%
# Initialize an empty list to store the content
story = []

try:
    # Open and read the file
    with open(file_path, encoding='unicode_escape') as f:
        corpus = f.read()
    raw_sent=sent_tokenize(corpus)
    for sent in raw_sent:
      story.append(simple_preprocess(sent))  # Add the file content to the story list


    print("File processed successfully.")
except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# File processed successfully.

# %%
story
# Out:
# [['the',
#   'mah',
#   'bh',
#   'rata',
#   'hah',
#   'bar',
#   'mah',
#   'sanskrit',
#   'iast',
#   'mah',
#   'bh',
#   'ratam',
#   'pronounced'],
#  ['is',
#   'one',
#   'of',
#   'the',
#   'two',
#   'major',
#   'smriti',
#   'texts',
#   'and',
#   'sanskrit',
#   'epics',
#   'of',
#   'ancient',
#   'india',
#   'revered',
#   'in',
#   'hinduism',
#   'the',
#   'other',
#   'being',
#   'the',
#   'ya'],
#  ['it',
#   'narrates',
#   'the',
#   'events',
#   'and',
#   'aftermath',
#   'of',
#   'the',
#   'kurukshetra',
#   'war',
#   'war',
#   'of',
#   'succession',
#   'between',
#   'two',
#   'groups',
#   'of',
#   'princely',
#   'cousins',
#   'the',
#   'kauravas',
#   'and',
#   'the',
#   'avas'],
#  ['part',
#   'of',
#   'series',
#   'on',
#   'hindu',
#   'mythology',
#   'sources',
#   'itihasa',
#   'ramayana',
#   'mahabharata',
#   'puranas',
#   'brahma',
#   'purana',
#   'brahmanda',
#   'purana',
#   'bhagavata',
#   'purana',
# ...

# %% [markdown]
# Key Components
# gensim.models.Word2Vec:
# This is the class used to create a Word2Vec model in Gensim.
# Word2Vec is a technique to generate dense vector representations (embeddings) of words in a way that captures semantic relationships between them.
# Parameters
# window=10:
# Definition: The maximum distance between the current word and the context words considered during training.
# Effect: A window size of 10 means the model will look at up to 10 words to the left and right of the current word to predict its neighbors (context).
# Interpretation: Larger windows capture more global context, while smaller windows capture more local context.
# min_count=5:
# Definition: The minimum number of occurrences a word must have in the corpus to be included in the vocabulary.
# Effect: Words that appear less than 5 times are ignored by the model.
# Reason: This helps reduce noise by excluding rare words that may not contribute meaningful information.
# vector_size=150:
# Definition: The size (or dimensionality) of the word vectors to be generated.
# Effect: Each word will be represented as a vector with 150 dimensions.
# Trade-off:
# Higher dimensions can capture more nuanced relationships but may require more computational resources and risk overfitting for small datasets.
# Lower dimensions are faster but might lose some representational power.
# Default Parameters (Optional)
# If not explicitly specified, the following default parameters will also be used:
#
# sg=0: The model uses the CBOW (Continuous Bag of Words) architecture. If set to 1, it uses Skip-Gram instead.
# epochs=5: The model will train for 5 iterations over the entire dataset.
# workers=3: Specifies the number of CPU threads used for training.
# What This Does
# The command initializes a Word2Vec model with the following characteristics:
#
# It focuses on the context within a window size of 10 words.
# It ignores rare words appearing fewer than 5 times in the corpus.
# It produces 150-dimensional embeddings for words in the vocabulary.

# %%
custom_model=gensim.models.Word2Vec(window=10,min_count=5,vector_size=150)

# %%
custom_model.build_vocab(story)

# %%
custom_model.corpus_count
# Out:
# 330

# %%
custom_model.epochs
# Out:
# 5

# %%
custom_model.corpus_total_words
# Out:
# 6758

# %%
custom_model.min_count
# Out:
# 5

# %%
custom_model.wv["king"]
# Out:
# array([ 0.00596559, -0.00128533, -0.0010617 , -0.00198131,  0.00033536,
#        -0.00431665, -0.00124498, -0.0057654 ,  0.00043869,  0.00095614,
#         0.00248523, -0.00191597,  0.00395371, -0.00471856,  0.00654447,
#         0.0003554 ,  0.00153034,  0.00290416,  0.00027957,  0.00173046,
#         0.00107643, -0.0064113 , -0.0020983 , -0.00172972, -0.00617521,
#         0.00229021,  0.00319987, -0.00138768,  0.00494508, -0.00080721,
#        -0.00018578,  0.00385496, -0.00564884, -0.00460724,  0.00490081,
#        -0.00438822,  0.0056453 ,  0.00356667, -0.00536421,  0.00560074,
#         0.00421216, -0.00447654, -0.00564182, -0.00588977,  0.00255414,
#         0.00422453, -0.00142315,  0.00089422, -0.00559575, -0.00341292,
#         0.00313616, -0.00604256, -0.00615814,  0.00067208, -0.00572326,
#        -0.00462527,  0.00316873,  0.00533704, -0.00490612,  0.00540407,
#         0.00625291,  0.00314127, -0.00293818,  0.00644683, -0.00515148,
# ...

# %%
custom_model.wv["king"].shape
# Out:
# (150,)

# %%
custom_model.wv.most_similar("pandavas")
# Out:
# [('yuga', 0.20295099914073944),
#  ('all', 0.19211795926094055),
#  ('five', 0.17269018292427063),
#  ('father', 0.1636694073677063),
#  ('hastinapura', 0.1532129943370819),
#  ('had', 0.14867344498634338),
#  ('into', 0.13896752893924713),
#  ('several', 0.13873040676116943),
#  ('snake', 0.13579913973808289),
#  ('this', 0.13434752821922302)]

# %%
custom_model.wv.most_similar("balarama")
# Out:
# [('wrote', 0.21244339644908905),
#  ('version', 0.19057202339172363),
#  ('and', 0.1736636906862259),
#  ('yuga', 0.17087163031101227),
#  ('brothers', 0.1597604751586914),
#  ('translating', 0.15720990300178528),
#  ('early', 0.15248382091522217),
#  ('work', 0.1495315581560135),
#  ('then', 0.14705611765384674),
#  ('king', 0.14270025491714478)]

# %% [markdown]
# Applying PCA

# %%
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# Task 1. Suppress vector dimension from 150 to 2 and 3 using Principal Component Analysis (PCA)

# %%
# Extract all word vectors from our trained Word2Vec model
word_vectors = custom_model.wv.vectors

# Initialize PCA with 2 components
pca2 = PCA(n_components=2)
# Initialize PCA with 3 components
pca3 = PCA(n_components=3)

# Fit PCA to the word vectors and transform them into 2 dimenssions
reduced_vectors2 = pca2.fit_transform(word_vectors)

# Fit PCA to the word vectors and transform them into 3 dimenssions
reduced_vectors3 = pca3.fit_transform(word_vectors)

# %% [markdown]
# Now let's compare the lenght of first word's vector before and after applying PCA.

# %%
reduced_vectors2.shape
# Out:
# (210, 2)

# %%
print(f"Length of first word's vector before PCA: {len(word_vectors[0])}")
print(f"Length of first word's vector after PCA (2 dimenssions): {len(reduced_vectors2[0])}")
# print(f"Length of first word's vector after PCA (3 dimenssions): {len(reduced_vectors3[0])}")
# Out:
# Length of first word's vector before PCA: 150
# Length of first word's vector after PCA (2 dimenssions): 2

# %% [markdown]
# Task 2. Plot the suppressed vectors in 2D & 3D graphs
# Because of the large number of words in our vocabulary, we'll use a small sample that consists of main characters in the Mahabharat Epic

# %%
# Main Characters
main_characters = [
    "Krishna", "Arjuna", "Yudhishthira", "Bhima", "Nakula", "Sahadeva",
    "Draupadi", "Karna", "Duryodhana", "Shakuni", "Dushasana", "Bhishma",
    "Dronacharya", "Ashwatthama", "Vidura", "Gandhari", "Kunti", "Subhadra",
    "Abhimanyu", "Shantanu", "Satyavati", "Amba", "Ambika", "Ambalika",
    "Pandu", "Dhritarashtra", "Ekalavya"
]

# Groups, Races, and Divine Beings
groups = [
    "Pandavas", "Kauravas", "Yadavas", "Nagvas", "Rakshasas", "Gandharvas",
    "Vanaras", "Devas", "Asuras", "Apsaras", "Siddhas", "Charanas", "Pishachas"
]

# Combine characters and groups into a single list
sample = main_characters + groups

# Apply lowering to all characters for each element in the sample list
sample = [word.lower() for word in sample]

# Print the resulting lowercase list
# print(sample)

# %%
# 'words' is a list of words from our vocabulary
words = list(custom_model.wv.key_to_index)

# 'sample_words' contains the words we want to plot
sample_words = [word for word in sample if word in words]

# 'sample_vectors2' contains the suppressed vectors of our sample words with 2 dimenssions
sample_vectors2 = [reduced_vectors2[words.index(word)] for word in sample_words]

# 'sample_vectors3' contains the suppressed vectors of our sample words with 3 dimenssions
sample_vectors3 = [reduced_vectors3[words.index(word)] for word in sample_words]

# %%
# Create a scatter plot
plt.figure(figsize=(14, 6))
plt.scatter([v[0] for v in sample_vectors2], [v[1] for v in sample_vectors2])

# Annotate points with words
for i, word in enumerate(sample_words):
    plt.annotate(word, xy=(sample_vectors2[i][0], sample_vectors2[i][1]))

plt.title("2D Visualization of Sampled Word Vectors using PCA")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.show()

# %%
# Create a 3D scatter plot
fig = plt.figure(figsize=(14, 10))
ax = fig.add_subplot(111, projection='3d')  # Create a 3D subplot

# Scatter the reduced vectors in 3D space
ax.scatter([v[0] for v in sample_vectors3],
           [v[1] for v in sample_vectors3],
           [v[2] for v in sample_vectors3])

# Annotate points with words
for i, word in enumerate(sample_words):
    ax.text(sample_vectors3[i][0],
            sample_vectors3[i][1],
            sample_vectors3[i][2], word)

# Set plot labels and title
ax.set_xlabel("Principal Component 1")
ax.set_ylabel("Principal Component 2")
ax.set_zlabel("Principal Component 3")
ax.set_title("3D Visualization of Sampled Word Vectors using PCA")

# Display the plot
plt.show()

# %% [markdown]
# Task 3. Check the similarity between our sample words before and after PCA

# %%
# Let's check the 5 most similar words for the word "Frodo" before applying PCA
krishna_before_pca = custom_model.wv.most_similar("krishna", topn=5)
print("Top 5 most similar words for Krishna before PCA:")
for word, similarity in krishna_before_pca:
    print(f"{word}: {similarity:.4f}")
# Out:
# Top 5 most similar words for Krishna before PCA:
# translating: 0.1990
# madri: 0.1895
# been: 0.1804
# manuscript: 0.1727
# sage: 0.1697

# %%
# Get the index of "krishna" in your vocabulary
krishna_index = words.index('krishna')

# Get the reduced vector for "krishna" (using the 2D reduced vectors here)
krishna_vector_pca = reduced_vectors2[krishna_index]

# Calculate cosine similarities between 'krishna_vector_pca' and all other reduced vectors
similarities = cosine_similarity([krishna_vector_pca], reduced_vectors2)

# Get the indices of the most similar words and their similarity scores, excluding "krishna" itself
most_similar_indices_scores = similarities.argsort()[0][-6:-1]
most_similar_scores = similarities[0][most_similar_indices_scores]

# Get the words corresponding to the most similar indices
most_similar_words_pca = [words[i] for i in most_similar_indices_scores]

# Print the results
print("Top 5 most similar words for krishna after PCA (2D):")
for word, score in zip(most_similar_words_pca, most_similar_scores):
    print(f"{word}: {score:.4f}")
# Out:
# Top 5 most similar words for krishna after PCA (2D):
# within: 0.9996
# their: 0.9996
# series: 0.9997
# pandava: 0.9998
# has: 0.9999

# %% [markdown]
# Conclusion
# As we can see even adding one more dimension (from 2 dimensions to 3 dimensions) help dramatically to get more of the most similar words we get back with the full 150 dimensions.
